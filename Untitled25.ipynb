# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Travel.csv")
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
df.shape
# Out:
# (4888, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   int64
#  2   Age                       4662 non-null   float64
#  3   TypeofContact             4863 non-null   object
#  4   CityTier                  4888 non-null   int64
#  5   DurationOfPitch           4637 non-null   float64
#  6   Occupation                4888 non-null   object
#  7   Gender                    4888 non-null   object
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4843 non-null   float64
#  10  ProductPitched            4888 non-null   object
#  11  PreferredPropertyStar     4862 non-null   float64
#  12  MaritalStatus             4888 non-null   object
# ...

# %%
df.dtypes
# Out:
# CustomerID                    int64
# ProdTaken                     int64
# Age                         float64
# TypeofContact                object
# CityTier                      int64
# DurationOfPitch             float64
# Occupation                   object
# Gender                       object
# NumberOfPersonVisiting        int64
# NumberOfFollowups           float64
# ProductPitched               object
# PreferredPropertyStar       float64
# MaritalStatus                object
# NumberOfTrips               float64
# Passport                      int64
# PitchSatisfactionScore        int64
# OwnCar                        int64
# NumberOfChildrenVisiting    float64
# Designation                  object
# MonthlyIncome               float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                         226
# TypeofContact                25
# CityTier                      0
# DurationOfPitch             251
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
df.tail()
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
#           Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 4883  Small Business    Male                       3                5.0
# 4884        Salaried    Male                       4                5.0
# 4885        Salaried  Female                       4                4.0
# 4886  Small Business    Male                       3                4.0
# 4887        Salaried    Male                       4                4.0
#
# ...

# %% [markdown]
# #Check for duplicates

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [CustomerID, ProdTaken, Age, TypeofContact, CityTier, DurationOfPitch, Occupation, Gender, NumberOfPersonVisiting, NumberOfFollowups, ProductPitched, PreferredPropertyStar, MaritalStatus, NumberOfTrips, Passport, PitchSatisfactionScore, OwnCar, NumberOfChildrenVisiting, Designation, MonthlyIncome]
# Index: []

# %% [markdown]
# #Seggregating categorical and numerical features

# %%
categoricalfeatures=[features for features in df.columns if df[features].dtypes=='object']
categoricalfeatures
# Out:
# ['TypeofContact',
#  'Occupation',
#  'Gender',
#  'ProductPitched',
#  'MaritalStatus',
#  'Designation']

# %%
numericalfeatures=[features for features in df.columns if df[features].dtypes!='object']
numericalfeatures
# Out:
# ['CustomerID',
#  'ProdTaken',
#  'Age',
#  'CityTier',
#  'DurationOfPitch',
#  'NumberOfPersonVisiting',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'Passport',
#  'PitchSatisfactionScore',
#  'OwnCar',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome']

# %%
for col in categoricalfeatures:
  print(f"{col} has {df[col].unique()}")
# Out:
# TypeofContact has ['Self Enquiry' 'Company Invited' nan]
# Occupation has ['Salaried' 'Free Lancer' 'Small Business' 'Large Business']
# Gender has ['Female' 'Male' 'Fe Male']
# ProductPitched has ['Deluxe' 'Basic' 'Standard' 'Super Deluxe' 'King']
# MaritalStatus has ['Single' 'Divorced' 'Married' 'Unmarried']
# Designation has ['Manager' 'Executive' 'Senior Manager' 'AVP' 'VP']

# %%
for col in numericalfeatures:
  print(f"{col} has {df[col].unique()}")
# Out:
# CustomerID has [200000 200001 200002 ... 204885 204886 204887]
# ProdTaken has [1 0]
# Age has [41. 49. 37. 33. nan 32. 59. 30. 38. 36. 35. 31. 34. 28. 29. 22. 53. 21.
#  42. 44. 46. 39. 24. 43. 50. 27. 26. 48. 55. 45. 56. 23. 51. 40. 54. 58.
#  20. 25. 19. 57. 52. 47. 18. 60. 61.]
# CityTier has [3 1 2]
# DurationOfPitch has [  6.  14.   8.   9.  30.  29.  33.  22.  21.  32.  25.  27.  11.  17.
#   15.  13.  12.  16.  10.  31.  18.  nan  24.  35.  28.  20.  26.  34.
#   23.   5.  19. 126.   7.  36. 127.]
# NumberOfPersonVisiting has [3 2 1 4 5]
# NumberOfFollowups has [ 3.  4.  2.  5. nan  1.  6.]
# PreferredPropertyStar has [ 3.  4.  5. nan]
# NumberOfTrips has [ 1.  2.  7.  5.  6.  3.  4. 19. 21.  8. nan 20. 22.]
# Passport has [1 0]
# PitchSatisfactionScore has [2 3 5 4 1]
# OwnCar has [1 0]
# NumberOfChildrenVisiting has [ 0.  2.  1. nan  3.]
# MonthlyIncome has [20993. 20130. 17090. ... 22097. 22995. 21471.]

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
df.drop('CustomerID',axis=1,inplace=True)

# %% [markdown]
# #ProdTaken

# %%
df['ProdTaken']
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 4883    1
# 4884    1
# 4885    1
# 4886    1
# 4887    1
# Name: ProdTaken, Length: 4888, dtype: int64

# %%
df['ProdTaken'].isnull().sum()
# Out:
# 0

# %%
sns.histplot(df['ProdTaken'])
# Out:
# <Axes: xlabel='ProdTaken', ylabel='Count'>

# %%
sns.relplot(x=df['ProdTaken'],y=df['MonthlyIncome'],data=df)

# %% [markdown]
# #Age

# %%
df['Age']
# Out:
# 0       41.0
# 1       49.0
# 2       37.0
# 3       33.0
# 4        NaN
#         ...
# 4883    49.0
# 4884    28.0
# 4885    52.0
# 4886    19.0
# 4887    36.0
# Name: Age, Length: 4888, dtype: float64

# %%
df['Age'].mean()
# Out:
# 37.62226512226512

# %%
median=df['Age'].median()
median
# Out:
# 36.0

# %%
df['Age']=df['Age'].fillna(median)
df['Age']
# Out:
# 0       41.0
# 1       49.0
# 2       37.0
# 3       33.0
# 4       36.0
#         ...
# 4883    49.0
# 4884    28.0
# 4885    52.0
# 4886    19.0
# 4887    36.0
# Name: Age, Length: 4888, dtype: float64

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.relplot(x=df['Age'],y=df['MonthlyIncome'],data=df,hue='ProdTaken')

# %% [markdown]
# #Type of Contact

# %%
df['TypeofContact']
# Out:
# 0          Self Enquiry
# 1       Company Invited
# 2          Self Enquiry
# 3       Company Invited
# 4          Self Enquiry
#              ...
# 4883       Self Enquiry
# 4884    Company Invited
# 4885       Self Enquiry
# 4886       Self Enquiry
# 4887       Self Enquiry
# Name: TypeofContact, Length: 4888, dtype: object

# %%
df['TypeofContact'].isnull().sum()
# Out:
# 25

# %%
df['TypeofContact'].mode()
# Out:
# 0    Self Enquiry
# Name: TypeofContact, dtype: object

# %%
df['TypeofContact']=df['TypeofContact'].fillna(df['TypeofContact'].mode()[0])
df['TypeofContact']
# Out:
# 0          Self Enquiry
# 1       Company Invited
# 2          Self Enquiry
# 3       Company Invited
# 4          Self Enquiry
#              ...
# 4883       Self Enquiry
# 4884    Company Invited
# 4885       Self Enquiry
# 4886       Self Enquiry
# 4887       Self Enquiry
# Name: TypeofContact, Length: 4888, dtype: object

# %%
df['TypeofContact'].isnull().sum()
# Out:
# 0

# %%
sns.catplot(df['TypeofContact'])

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
TOC=label.fit_transform(df['TypeofContact'])
df['TypeofContact']=TOC

# %%
df['TypeofContact']
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 4883    1
# 4884    0
# 4885    1
# 4886    1
# 4887    1
# Name: TypeofContact, Length: 4888, dtype: int64

# %%
sns.histplot(df['TypeofContact'])
# Out:
# <Axes: xlabel='TypeofContact', ylabel='Count'>

# %%
sns.relplot(x=df['TypeofContact'],y=df['NumberOfTrips'])

# %% [markdown]
# #City Tier

# %%
df['CityTier']
# Out:
# 0       3
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 4883    3
# 4884    1
# 4885    3
# 4886    3
# 4887    1
# Name: CityTier, Length: 4888, dtype: int64

# %%
df['CityTier'].isnull().sum()
# Out:
# 0

# %%
sns.histplot(df['CityTier'])
# Out:
# <Axes: xlabel='CityTier', ylabel='Count'>

# %%
sns.relplot(x=df['CityTier'],y=df['MonthlyIncome'],data=df)

# %%
X=df[df['CityTier']==1]
X
# Out:
#       ProdTaken   Age  TypeofContact  CityTier  DurationOfPitch  \
# 1             0  49.0              0         1             14.0
# 2             1  37.0              1         1              8.0
# 3             0  33.0              0         1              9.0
# 4             0  36.0              1         1              8.0
# 5             0  32.0              0         1              8.0
# ...         ...   ...            ...       ...              ...
# 4877          1  39.0              0         1             16.0
# 4878          1  35.0              1         1             17.0
# 4880          1  59.0              1         1             28.0
# 4884          1  28.0              0         1             31.0
# 4887          1  36.0              1         1             14.0
#
#           Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 1           Salaried    Male                       3                4.0
# ...

# %%
X.ProdTaken.max()
# Out:
# 1

# %%
X.MonthlyIncome.max()
# Out:
# 98678.0

# %%
X.NumberOfPersonVisiting.max()
# Out:
# 5

# %%
X.NumberOfTrips.value_counts()
# Out:
# 2.0     934
# 3.0     711
# 1.0     387
# 4.0     322
# 5.0     307
# 6.0     206
# 7.0     145
# 8.0      75
# 19.0      1
# 21.0      1
# 20.0      1
# 22.0      1
# Name: NumberOfTrips, dtype: int64

# %% [markdown]
# #DurationOfPitch

# %%
df['DurationOfPitch']
# Out:
# 0        6.0
# 1       14.0
# 2        8.0
# 3        9.0
# 4        8.0
#         ...
# 4883     9.0
# 4884    31.0
# 4885    17.0
# 4886    16.0
# 4887    14.0
# Name: DurationOfPitch, Length: 4888, dtype: float64

# %%
df['DurationOfPitch'].isnull().sum()
# Out:
# 251

# %%
df['DurationOfPitch'].mean()
# Out:
# 15.490834591330602

# %%
median=df['DurationOfPitch'].median()
median
# Out:
# 13.0

# %%
sns.boxplot(df['DurationOfPitch'])
# Out:
# <Axes: ylabel='DurationOfPitch'>

# %%
df['DurationOfPitch']=df['DurationOfPitch'].fillna(median)
df['DurationOfPitch']
# Out:
# 0        6.0
# 1       14.0
# 2        8.0
# 3        9.0
# 4        8.0
#         ...
# 4883     9.0
# 4884    31.0
# 4885    17.0
# 4886    16.0
# 4887    14.0
# Name: DurationOfPitch, Length: 4888, dtype: float64

# %%
df['DurationOfPitch'].isnull().sum()
# Out:
# 0

# %%
sns.relplot(x=df['DurationOfPitch'],y=df['CityTier'],data=df)

# %%
df.columns
# Out:
# Index(['ProdTaken', 'Age', 'TypeofContact', 'CityTier', 'DurationOfPitch',
#        'Occupation', 'Gender', 'NumberOfPersonVisiting', 'NumberOfFollowups',
#        'ProductPitched', 'PreferredPropertyStar', 'MaritalStatus',
#        'NumberOfTrips', 'Passport', 'PitchSatisfactionScore', 'OwnCar',
#        'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %% [markdown]
# #Occupation

# %%
df['Occupation'].unique()
# Out:
# array(['Salaried', 'Free Lancer', 'Small Business', 'Large Business'],
#       dtype=object)

# %%
sns.catplot(df['Occupation'])

# %%
DOP=label.fit_transform(df['Occupation'])
DOP
# Out:
# array([2, 2, 0, ..., 2, 3, 2])

# %%
df['Occupation']=DOP

# %%
df['Occupation'].unique()
# Out:
# array([2, 0, 3, 1])

# %%
df['Occupation'].isnull().sum()
# Out:
# 0

# %%
sns.histplot(df['Occupation'])
# Out:
# <Axes: xlabel='Occupation', ylabel='Count'>

# %%
sns.relplot(x=df['Occupation'],y=df['MonthlyIncome'],data=df)

# %%
X=df[df['Occupation']==2]

# %%
X.NumberOfTrips.value_counts()
# Out:
# 2.0     711
# 3.0     524
# 1.0     282
# 4.0     258
# 5.0     257
# 6.0     131
# 7.0      84
# 8.0      49
# 21.0      1
# 22.0      1
# Name: NumberOfTrips, dtype: int64

# %%
X.CityTier.value_counts()
# Out:
# 1    1682
# 3     548
# 2     138
# Name: CityTier, dtype: int64

# %%
X.MonthlyIncome.max()
# Out:
# 98678.0

# %%
X.MonthlyIncome.min()
# Out:
# 16051.0

# %% [markdown]
# #Gender

# %%
df['Gender']
# Out:
# 0       Female
# 1         Male
# 2         Male
# 3       Female
# 4         Male
#          ...
# 4883      Male
# 4884      Male
# 4885    Female
# 4886      Male
# 4887      Male
# Name: Gender, Length: 4888, dtype: object

# %%
df['Gender'].isnull().sum()
# Out:
# 0

# %%
gender=label.fit_transform(df['Gender'])
gender
# Out:
# array([1, 2, 2, ..., 1, 2, 2])

# %%
df['Gender']=gender

# %%
df['Gender']
# Out:
# 0       1
# 1       2
# 2       2
# 3       1
# 4       2
#        ..
# 4883    2
# 4884    2
# 4885    1
# 4886    2
# 4887    2
# Name: Gender, Length: 4888, dtype: int64

# %%
sns.relplot(x=df['Gender'],y=df['MonthlyIncome'],data=df,hue='NumberOfTrips')

# %%
df.columns
# Out:
# Index(['ProdTaken', 'Age', 'TypeofContact', 'CityTier', 'DurationOfPitch',
#        'Occupation', 'Gender', 'NumberOfPersonVisiting', 'NumberOfFollowups',
#        'ProductPitched', 'PreferredPropertyStar', 'MaritalStatus',
#        'NumberOfTrips', 'Passport', 'PitchSatisfactionScore', 'OwnCar',
#        'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
df.corr()
# Out:
# <ipython-input-254-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                           ProdTaken       Age  TypeofContact  CityTier  \
# ProdTaken                  1.000000 -0.143753      -0.049492  0.086852
# Age                       -0.143753  1.000000       0.021960 -0.012754
# TypeofContact             -0.049492  0.021960       1.000000 -0.009645
# CityTier                   0.086852 -0.012754      -0.009645  1.000000
# DurationOfPitch            0.076481 -0.006261      -0.027536  0.019445
# Occupation                -0.041042  0.026969       0.003434  0.131834
# Gender                     0.031376 -0.039846       0.012584 -0.037895
# NumberOfPersonVisiting     0.009627  0.017856      -0.003545 -0.001671
# ...

# %% [markdown]
# #NumberOfPersonVisiting

# %%
df['NumberOfPersonVisiting'].isnull().sum()
# Out:
# 0

# %%
sns.relplot(x=df['NumberOfPersonVisiting'],y=df['ProdTaken'],data=df)

# %% [markdown]
# #NumberofFollowups

# %%
df['NumberOfFollowups'].isnull().sum()
# Out:
# 45

# %%
df['NumberOfFollowups'].mean()
# Out:
# 3.708445178608301

# %%
median=df['NumberOfFollowups'].median()
median
# Out:
# 4.0

# %%
sns.boxplot(df['NumberOfFollowups'])
# Out:
# <Axes: ylabel='NumberOfFollowups'>

# %%
df['NumberOfFollowups']=df['NumberOfFollowups'].fillna(median)
df['NumberOfFollowups']
# Out:
# 0       3.0
# 1       4.0
# 2       4.0
# 3       3.0
# 4       3.0
#        ...
# 4883    5.0
# 4884    5.0
# 4885    4.0
# 4886    4.0
# 4887    4.0
# Name: NumberOfFollowups, Length: 4888, dtype: float64

# %%
df['NumberOfFollowups'].isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    ProdTaken   Age  TypeofContact  CityTier  DurationOfPitch  Occupation  \
# 0          1  41.0              1         3              6.0           2
# 1          0  49.0              0         1             14.0           2
# 2          1  37.0              1         1              8.0           0
# 3          0  33.0              0         1              9.0           2
# 4          0  36.0              1         1              8.0           3
#
#    Gender  NumberOfPersonVisiting  NumberOfFollowups ProductPitched  \
# 0       1                       3                3.0         Deluxe
# 1       2                       3                4.0         Deluxe
# 2       2                       3                4.0          Basic
# 3       1                       2                3.0          Basic
# 4       2                       2                3.0          Basic
#
#    PreferredPropertyStar MaritalStatus  NumberOfTrips  Passport  \
# ...

# %%
df['ProductPitched']
# Out:
# 0         Deluxe
# 1         Deluxe
# 2          Basic
# 3          Basic
# 4          Basic
#           ...
# 4883      Deluxe
# 4884       Basic
# 4885    Standard
# 4886       Basic
# 4887       Basic
# Name: ProductPitched, Length: 4888, dtype: object

# %%
NOF=label.fit_transform(df['ProductPitched'])
NOF
# Out:
# array([1, 1, 0, ..., 3, 0, 0])

# %%
df['ProductPitched']=NOF

# %%
df['ProductPitched']
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 4883    1
# 4884    0
# 4885    3
# 4886    0
# 4887    0
# Name: ProductPitched, Length: 4888, dtype: int64

# %%
df.head()
# Out:
#    ProdTaken   Age  TypeofContact  CityTier  DurationOfPitch  Occupation  \
# 0          1  41.0              1         3              6.0           2
# 1          0  49.0              0         1             14.0           2
# 2          1  37.0              1         1              8.0           0
# 3          0  33.0              0         1              9.0           2
# 4          0  36.0              1         1              8.0           3
#
#    Gender  NumberOfPersonVisiting  NumberOfFollowups  ProductPitched  \
# 0       1                       3                3.0               1
# 1       2                       3                4.0               1
# 2       2                       3                4.0               0
# 3       1                       2                3.0               0
# 4       2                       2                3.0               0
#
#    PreferredPropertyStar MaritalStatus  NumberOfTrips  Passport  \
# ...

# %% [markdown]
# #Preferred Property Star

# %%
df['PreferredPropertyStar'].isnull().sum()
# Out:
# 26

# %%
df['PreferredPropertyStar'].mean()
# Out:
# 3.581036610448375

# %%
median=df['PreferredPropertyStar'].median()
median
# Out:
# 3.0

# %%
sns.boxplot(df['PreferredPropertyStar'])
# Out:
# <Axes: ylabel='PreferredPropertyStar'>

# %%
df['PreferredPropertyStar']=df['PreferredPropertyStar'].fillna(median)
df['PreferredPropertyStar']
# Out:
# 0       3.0
# 1       4.0
# 2       3.0
# 3       3.0
# 4       4.0
#        ...
# 4883    4.0
# 4884    3.0
# 4885    4.0
# 4886    3.0
# 4887    4.0
# Name: PreferredPropertyStar, Length: 4888, dtype: float64

# %%
df['PreferredPropertyStar'].isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    ProdTaken   Age  TypeofContact  CityTier  DurationOfPitch  Occupation  \
# 0          1  41.0              1         3              6.0           2
# 1          0  49.0              0         1             14.0           2
# 2          1  37.0              1         1              8.0           0
# 3          0  33.0              0         1              9.0           2
# 4          0  36.0              1         1              8.0           3
#
#    Gender  NumberOfPersonVisiting  NumberOfFollowups  ProductPitched  \
# 0       1                       3                3.0               1
# 1       2                       3                4.0               1
# 2       2                       3                4.0               0
# 3       1                       2                3.0               0
# 4       2                       2                3.0               0
#
#    PreferredPropertyStar MaritalStatus  NumberOfTrips  Passport  \
# ...

# %% [markdown]
# #Marital Status

# %%
df['MaritalStatus']
# Out:
# 0          Single
# 1        Divorced
# 2          Single
# 3        Divorced
# 4        Divorced
#           ...
# 4883    Unmarried
# 4884       Single
# 4885      Married
# 4886       Single
# 4887    Unmarried
# Name: MaritalStatus, Length: 4888, dtype: object

# %%
MS=label.fit_transform(df['MaritalStatus'])
MS
# Out:
# array([2, 0, 2, ..., 1, 2, 3])

# %%
df['MaritalStatus']=MS

# %%
df
# Out:
#       ProdTaken   Age  TypeofContact  CityTier  DurationOfPitch  Occupation  \
# 0             1  41.0              1         3              6.0           2
# 1             0  49.0              0         1             14.0           2
# 2             1  37.0              1         1              8.0           0
# 3             0  33.0              0         1              9.0           2
# 4             0  36.0              1         1              8.0           3
# ...         ...   ...            ...       ...              ...         ...
# 4883          1  49.0              1         3              9.0           3
# 4884          1  28.0              0         1             31.0           2
# 4885          1  52.0              1         3             17.0           2
# 4886          1  19.0              1         3             16.0           3
# 4887          1  36.0              1         1             14.0           2
#
# ...

# %% [markdown]
# # NumberOfTrips

# %%
df['NumberOfTrips']
# Out:
# 0       1.0
# 1       2.0
# 2       7.0
# 3       2.0
# 4       1.0
#        ...
# 4883    2.0
# 4884    3.0
# 4885    7.0
# 4886    3.0
# 4887    3.0
# Name: NumberOfTrips, Length: 4888, dtype: float64

# %%
df['NumberOfTrips'].isnull().sum()
# Out:
# 140

# %%
df['NumberOfTrips'].mean()
# Out:
# 3.236520640269587

# %%
median=df['NumberOfTrips'].median()
median
# Out:
# 3.0

# %%
df['NumberOfTrips']=df['NumberOfTrips'].fillna(median)
df['NumberOfTrips']
# Out:
# 0       1.0
# 1       2.0
# 2       7.0
# 3       2.0
# 4       1.0
#        ...
# 4883    2.0
# 4884    3.0
# 4885    7.0
# 4886    3.0
# 4887    3.0
# Name: NumberOfTrips, Length: 4888, dtype: float64

# %%
df['NumberOfTrips'].isnull().sum()
# Out:
# 0

# %%
df
# Out:
#       ProdTaken   Age  TypeofContact  CityTier  DurationOfPitch  Occupation  \
# 0             1  41.0              1         3              6.0           2
# 1             0  49.0              0         1             14.0           2
# 2             1  37.0              1         1              8.0           0
# 3             0  33.0              0         1              9.0           2
# 4             0  36.0              1         1              8.0           3
# ...         ...   ...            ...       ...              ...         ...
# 4883          1  49.0              1         3              9.0           3
# 4884          1  28.0              0         1             31.0           2
# 4885          1  52.0              1         3             17.0           2
# 4886          1  19.0              1         3             16.0           3
# 4887          1  36.0              1         1             14.0           2
#
# ...

# %% [markdown]
# #Passport

# %%
df['Passport'].isnull().sum()
# Out:
# 0

# %%
df['PitchSatisfactionScore'].isnull().sum()
# Out:
# 0

# %%
df['OwnCar'].isnull().sum()
# Out:
# 0

# %%
df['NumberOfChildrenVisiting'].isnull().sum()
# Out:
# 66

# %%
df['NumberOfChildrenVisiting'].mean()
# Out:
# 1.1872666943177106

# %%
median=df['NumberOfChildrenVisiting'].median()
median
# Out:
# 1.0

# %%
df['NumberOfChildrenVisiting']=df['NumberOfChildrenVisiting'].fillna(median)
df['NumberOfChildrenVisiting']
# Out:
# 0       0.0
# 1       2.0
# 2       0.0
# 3       1.0
# 4       0.0
#        ...
# 4883    1.0
# 4884    2.0
# 4885    3.0
# 4886    2.0
# 4887    2.0
# Name: NumberOfChildrenVisiting, Length: 4888, dtype: float64

# %%
df['NumberOfChildrenVisiting'].isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    ProdTaken   Age  TypeofContact  CityTier  DurationOfPitch  Occupation  \
# 0          1  41.0              1         3              6.0           2
# 1          0  49.0              0         1             14.0           2
# 2          1  37.0              1         1              8.0           0
# 3          0  33.0              0         1              9.0           2
# 4          0  36.0              1         1              8.0           3
#
#    Gender  NumberOfPersonVisiting  NumberOfFollowups  ProductPitched  \
# 0       1                       3                3.0               1
# 1       2                       3                4.0               1
# 2       2                       3                4.0               0
# 3       1                       2                3.0               0
# 4       2                       2                3.0               0
#
#    PreferredPropertyStar  MaritalStatus  NumberOfTrips  Passport  \
# ...

# %%
df['Designation'].isnull().sum()
# Out:
# 0

# %%
d=label.fit_transform(df['Designation'])
d
# Out:
# array([2, 2, 1, ..., 3, 1, 1])

# %%
df['Designation']=d

# %%
df
# Out:
#       ProdTaken   Age  TypeofContact  CityTier  DurationOfPitch  Occupation  \
# 0             1  41.0              1         3              6.0           2
# 1             0  49.0              0         1             14.0           2
# 2             1  37.0              1         1              8.0           0
# 3             0  33.0              0         1              9.0           2
# 4             0  36.0              1         1              8.0           3
# ...         ...   ...            ...       ...              ...         ...
# 4883          1  49.0              1         3              9.0           3
# 4884          1  28.0              0         1             31.0           2
# 4885          1  52.0              1         3             17.0           2
# 4886          1  19.0              1         3             16.0           3
# 4887          1  36.0              1         1             14.0           2
#
# ...

# %% [markdown]
# #Monthly Income

# %%
df['MonthlyIncome'].isnull().sum()
# Out:
# 233

# %%
df['MonthlyIncome'].mean()
# Out:
# 23619.85349087003

# %%
median=df['MonthlyIncome'].median()
median
# Out:
# 22347.0

# %%
sns.boxplot(df['MonthlyIncome'])
# Out:
# <Axes: ylabel='MonthlyIncome'>

# %%
df['MonthlyIncome']=df['MonthlyIncome'].fillna(median)
df['MonthlyIncome']
# Out:
# 0       20993.0
# 1       20130.0
# 2       17090.0
# 3       17909.0
# 4       18468.0
#          ...
# 4883    26576.0
# 4884    21212.0
# 4885    31820.0
# 4886    20289.0
# 4887    24041.0
# Name: MonthlyIncome, Length: 4888, dtype: float64

# %%
df['MonthlyIncome'].isnull().sum()
# Out:
# 0

# %%
df.corr()
# Out:
#                           ProdTaken       Age  TypeofContact  CityTier  \
# ProdTaken                  1.000000 -0.143753      -0.049492  0.086852
# Age                       -0.143753  1.000000       0.021960 -0.012754
# TypeofContact             -0.049492  0.021960       1.000000 -0.009645
# CityTier                   0.086852 -0.012754      -0.009645  1.000000
# DurationOfPitch            0.076481 -0.006261      -0.027536  0.019445
# Occupation                -0.041042  0.026969       0.003434  0.131834
# Gender                     0.031376 -0.039846       0.012584 -0.037895
# NumberOfPersonVisiting     0.009627  0.017856      -0.003545 -0.001671
# NumberOfFollowups          0.111560  0.001682      -0.016214  0.024333
# ProductPitched            -0.161262  0.449536       0.001658  0.141485
# PreferredPropertyStar      0.098704 -0.015932       0.031166 -0.008479
# MaritalStatus              0.147186 -0.092494      -0.034826  0.035707
# ...

# %%
df.drop('Age',axis=1,inplace=True)

# %%
df.drop('TypeofContact',axis=1,inplace=True)

# %%
df.drop('Occupation',axis=1,inplace=True)

# %%
df.drop('ProductPitched',axis=1,inplace=True)

# %%
df.drop('OwnCar',axis=1,inplace=True)

# %%
df.drop('Designation',axis=1,inplace=True)

# %%
df.drop('CityTier',axis=1,inplace=True)

# %%
df.drop('DurationOfPitch',axis=1,inplace=True)

# %%
df.drop('PreferredPropertyStar',axis=1,inplace=True)

# %%
df.drop('MaritalStatus',axis=1,inplace=True)

# %%
df.drop('NumberOfTrips',axis=1,inplace=True)

# %%
df.drop('Passport',axis=1,inplace=True)

# %%
df.drop('PitchSatisfactionScore',axis=1,inplace=True)

# %%
df
# Out:
#       ProdTaken  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0             1       1                       3                3.0
# 1             0       2                       3                4.0
# 2             1       2                       3                4.0
# 3             0       1                       2                3.0
# 4             0       2                       2                3.0
# ...         ...     ...                     ...                ...
# 4883          1       2                       3                5.0
# 4884          1       2                       4                5.0
# 4885          1       1                       4                4.0
# 4886          1       2                       3                4.0
# 4887          1       2                       4                4.0
#
#       NumberOfChildrenVisiting  MonthlyIncome
# 0                          0.0        20993.0
# 1                          2.0        20130.0
# ...

# %%
X=df[['ProdTaken','Gender','NumberOfPersonVisiting','NumberOfFollowups','NumberOfChildrenVisiting']]
Y=df['MonthlyIncome']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor(n_estimators=100)
model.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
Y_test
# Out:
# 2507    26315.0
# 1507    17014.0
# 704     22823.0
# 4026    36006.0
# 489     31627.0
#          ...
# 2656    28659.0
# 2887    22572.0
# 1321    17105.0
# 3431    29274.0
# 3833    23681.0
# Name: MonthlyIncome, Length: 978, dtype: float64

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([24828.42000806, 22056.8955753 , 22200.17041238, 19882.68138562,
#        22185.39211455, 22258.35439538, 26429.53756951, 21960.51349027,
#        22200.17041238, 21283.92052182, 21220.02041734, 25538.00107766,
#        24876.60883387, 25688.93984394, 24506.52681508, 25346.21388284,
#        26123.73762098, 25346.21388284, 24876.60883387, 22200.17041238,
#        22258.35439538, 24913.85358404, 20739.14525125, 26794.9545891 ,
#        25688.93984394, 25727.06427468, 21238.97228328, 25236.47048845,
#        22200.17041238, 22285.21210311, 25026.10136078, 22794.53802256,
#        22642.7728685 , 22200.17041238, 26779.77432801, 25538.00107766,
#        21960.51349027, 22086.48755525, 24913.85358404, 21960.51349027,
#        20734.21275674, 26429.53756951, 24876.60883387, 21960.51349027,
#        22285.21210311, 24153.41391049, 23412.64598922, 22185.39211455,
#        22794.53802256, 26649.97680168, 25026.10136078, 22285.21210311,
# ...

# %%
from sklearn.metrics import r2_score
r2_score(y_pred,Y_test)
# Out:
# -5.329735211901033

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([24620.88434661, 24181.48712579, 23210.43996747, 22178.84974819,
#        22581.7323757 , 22256.50722589, 25193.6771685 , 22666.10542415,
#        23210.43996747, 20338.24289674, 22263.22279664, 24259.1446035 ,
#        24868.4520187 , 25290.73482278, 24603.76992987, 26184.12450339,
#        25307.84923952, 26184.12450339, 24868.4520187 , 23210.43996747,
#        22256.50722589, 24506.71227559, 22962.87229538, 25900.04223799,
#        25290.73482278, 24265.86017424, 20520.83769696, 25936.5568313 ,
#        23210.43996747, 22504.07489799, 23897.40486039, 24668.74280175,
#        22588.44794644, 23210.43996747, 24591.08532404, 24259.1446035 ,
#        22666.10542415, 23819.74738268, 24506.71227559, 22666.10542415,
#        22601.13255227, 25193.6771685 , 24868.4520187 , 22666.10542415,
#        22504.07489799, 23132.78248977, 23191.0397909 , 22581.7323757 ,
#        24668.74280175, 24584.3697533 , 23897.40486039, 22504.07489799,
# ...
